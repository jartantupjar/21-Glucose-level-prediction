# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from methods import *
# Out:
# C:\Users\ndrs\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
raw_data=pd.read_excel('COEFF-04-08-2018.xlsx',sheet_name='Standard Data',index_col=0).T
raw_data.reset_index(drop=True,inplace=True)
raw_data=raw_data[:-4]
raw_data.dropna(inplace=True,axis=1)
raw_data.rename(columns={"BG (mg/dl)": "BG VAL"},inplace=True)
raw_data.head(3)
# Out:
# Variables Var1 Var2 Var3 Var4 Var5 Var6 Var7 Var8 Var9 Var10  ...   Var72  \
# 0          359  362  362  462  481  382  344  475  498   469  ...     531
# 1          372  369  405  373  450  386  435  338  409   366  ...     440
# 2          418  392  391  420  382  407  401  383  448   402  ...     403
#
# Variables Var73 Var74 Var75 Var76 Var77 Var78 Var79 Var80 BG VAL
# 0           533   521   535   535   538   538   540   540    102
# 1           394   386   422   377   430   398   378   423    102
# 2           393   384   462   412   376   410   430   402    102
#
# [3 rows x 81 columns]

# %%
X,y=raw_data.drop(['BG VAL'],axis=1),raw_data['BG VAL']
random_state=42

# %%
summary_data=gen_summary_data(X)
summary_data.drop(['min','mode','max-min'],axis=1,inplace=True)
summary_data.head(3)
# Out:
#         avg        std
# 0  510.0250  45.271606
# 1  397.5500  28.524429
# 2  404.2625  27.044616

# %%
x_train,x_test,y_train,y_test=train_test_split(summary_data,y,test_size=0.1,random_state=random_state)

# %%
clf_models=[LinearRegression(),
            RandomForestRegressor(random_state=random_state),
            GradientBoostingRegressor(random_state=random_state),
            KNeighborsRegressor(),
            AdaBoostRegressor(random_state=random_state),
            MLPRegressor()
    ]   
get_model_prediction(x_train,y_train,x_test,y_test,clf_models,True,True)
# Out:
# **Model name:  LinearRegression
# [206.65951726 177.80213945 215.46018799 191.83764431 283.59252045
#  194.4313394  212.73484088 195.8473966  190.13758129 201.47606434
#  216.8564671  232.94265647 185.02787285 203.18714193 224.23488064]
#  ERROR MEASURES
# Root Mean Squared Error:  94.76548369071735
# Mean Absolute Error:  87.3439682982812
# Mean Absolute Percent Error:  42.4825120743454
# R2 score:  -13.696889541066977
#     BG VAL        pred
# 117    103  206.659517
# 19     115  177.802139
# 82     132  215.460188
# 97     249  191.837644
# 56     349  283.592520
# 12     143  194.431339
# 132    109  212.734841
# 65     347  195.847397
# 66     347  190.137581
# 18     143  201.476064
# 51     349  216.856467
# 78     132  232.942656
# 94     249  185.027873
# 133    109  203.187142
# 100    249  224.234881
# **Model name:  RandomForestRegressor
# [165.  228.1 173.7 262.8 321.1 233.2 185.2 136.8 155.9 172.8 280.8 264.4
#  115.  121.8 349.6]
#  ERROR MEASURES
# Root Mean Squared Error:  104.97565432041851
# Mean Absolute Error:  86.93333333333334
# Mean Absolute Percent Error:  48.57193217983364
# R2 score:  -1.2376793180447967
#     BG VAL   pred
# 117    103  165.0
# 19     115  228.1
# 82     132  173.7
# 97     249  262.8
# 56     349  321.1
# 12     143  233.2
# 132    109  185.2
# 65     347  136.8
# 66     347  155.9
# 18     143  172.8
# 51     349  280.8
# 78     132  264.4
# 94     249  115.0
# 133    109  121.8
# 100    249  349.6
# **Model name:  GradientBoostingRegressor
# [144.59817189 204.38655463 174.8401395  262.89468482 272.44855162
#  241.11624158 218.42492858  91.00913346 186.73525576 173.30726654
#  273.15737267 283.59412856 156.80018096 164.55733257 395.57368747]
#  ERROR MEASURES
# Root Mean Squared Error:  113.47488297925113
# Mean Absolute Error:  96.00950944407592
# Mean Absolute Percent Error:  54.44037395496103
# R2 score:  -1.4927463389407816
#     BG VAL        pred
# 117    103  144.598172
# 19     115  204.386555
# 82     132  174.840140
# 97     249  262.894685
# 56     349  272.448552
# 12     143  241.116242
# 132    109  218.424929
# 65     347   91.009133
# 66     347  186.735256
# 18     143  173.307267
# 51     349  273.157373
# 78     132  283.594129
# 94     249  156.800181
# 133    109  164.557333
# 100    249  395.573687
# **Model name:  KNeighborsRegressor
# [238.6 149.8 217.2 237.0 368.4 187.0 208.0 137.0 148.6 187.0 245.8 238.6
#  135.8 137.0 215.4]
#  ERROR MEASURES
# Root Mean Squared Error:  103.68360847629998
# Mean Absolute Error:  84.46666666666665
# Mean Absolute Percent Error:  47.808540782729835
# R2 score:  -2.0548121345438393
#     BG VAL   pred
# 117    103  238.6
# 19     115  149.8
# 82     132  217.2
# 97     249    237
# 56     349  368.4
# 12     143    187
# 132    109    208
# 65     347    137
# 66     347  148.6
# 18     143    187
# 51     349  245.8
# 78     132  238.6
# 94     249  135.8
# 133    109    137
# 100    249  215.4
# **Model name:  AdaBoostRegressor
# [194.14285714 232.9        215.18032787 233.9375     339.06666667
#  215.18032787 233.6875     170.30232558 198.96153846 170.30232558
#  258.16666667 239.13333333 115.17647059 194.14285714 318.        ]
#  ERROR MEASURES
# Root Mean Squared Error:  101.23868815210764
# Mean Absolute Error:  90.1372240649097
# Mean Absolute Percent Error:  45.894331253508746
# R2 score:  -2.5058391963022797
#     BG VAL        pred
# 117    103  194.142857
# 19     115  232.900000
# 82     132  215.180328
# 97     249  233.937500
# 56     349  339.066667
# 12     143  215.180328
# 132    109  233.687500
# 65     347  170.302326
# 66     347  198.961538
# 18     143  170.302326
# 51     349  258.166667
# 78     132  239.133333
# 94     249  115.176471
# 133    109  194.142857
# 100    249  318.000000
# **Model name:  MLPRegressor
# [199.34477971 275.52324641 288.40924503 247.03866459 302.62090516
#  258.12168804 183.18708668 194.22496257 214.87686427 265.23714003
#  225.91944421 203.47873369 187.2415602  190.47014172 221.47659895]
#  ERROR MEASURES
# Root Mean Squared Error:  105.71382370490498
# Mean Absolute Error:  94.89153742374091
# Mean Absolute Percent Error:  41.73771348616057
# R2 score:  -6.654217529025753
#     BG VAL        pred
# 117    103  199.344780
# 19     115  275.523246
# 82     132  288.409245
# 97     249  247.038665
# 56     349  302.620905
# 12     143  258.121688
# 132    109  183.187087
# 65     347  194.224963
# 66     347  214.876864
# 18     143  265.237140
# 51     349  225.919444
# 78     132  203.478734
# 94     249  187.241560
# 133    109  190.470142
# 100    249  221.476599
# array([0.38398669, 0.61601331])

# %% [markdown]
# ## Linear Coefficient

# %% [markdown]
# ### Using 90% of data

# %%
model = LinearRegression()
model.fit(x_train, y_train)
pred=model.predict(x_test)
clf_metrics=acc_score(y_test,pred)
plot_test_data(y_test,pred)
intercept = model.intercept_
print('the intercept of the linear model is',intercept)
for idx, col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name, model.coef_[idx]))
# Out:
#  ERROR MEASURES
# Root Mean Squared Error:  94.76548369071735
# Mean Absolute Error:  87.3439682982812
# Mean Absolute Percent Error:  42.4825120743454
# R2 score:  -13.696889541066977
#     BG VAL        pred
# 117    103  206.659517
# 19     115  177.802139
# 82     132  215.460188
# 97     249  191.837644
# 56     349  283.592520
# 12     143  194.431339
# 132    109  212.734841
# 65     347  195.847397
# 66     347  190.137581
# 18     143  201.476064
# 51     349  216.856467
# 78     132  232.942656
# 94     249  185.027873
# 133    109  203.187142
# 100    249  224.234881
# the intercept of the linear model is 67.82674221129395
# The coefficient for avg is 0.09408134221425317
# The coefficient for std is 1.2717836470927963

# %% [markdown]
# ### Using all the data

# %%
model = LinearRegression()
model.fit(summary_data, y)
#pred=model.predict(x_test)
#clf_metrics=acc_score(y_test,pred)
#plot_test_data(y_test,pred)
intercept = model.intercept_
print('the intercept of the linear model is',intercept)
for idx, col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name, model.coef_[idx]))
# Out:
# the intercept of the linear model is 69.64370981091338
# The coefficient for avg is 0.09048417288041681
# The coefficient for std is 1.2752519254076995

# %% [markdown]
# ## load test data

# %%
new_data=pd.read_excel('STANDARDS-WEARABLE-NATRAJ PREDICTION.xlsx',sheet_name='PREDICTION-DETAILS',header=None,
                      usecols="G", na_values=['Orig ADC']).dropna().T
y_test=new_data[0]
x_test=new_data.drop([0],axis=1)
test_data=gen_summary_data(x_test)
test_data.head(3)

# %%
clf_models=[LinearRegression(),
            RandomForestRegressor(random_state=random_state),
            GradientBoostingRegressor(random_state=random_state),
            SGDRegressor(random_state=random_state),
            KNeighborsRegressor(),
            AdaBoostRegressor(random_state=random_state),
            MLPRegressor()
    ]
get_model_prediction(summary_data,y,test_data,None,clf_models)
print('Actual Glucose Level',y_test)
