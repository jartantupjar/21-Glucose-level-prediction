# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
# %matplotlib inline
from methods import *
from IPython.display import display
# Out:
# C:\Users\ndrs\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
raw_data=pd.read_excel('COEFF-04-08-2018.xlsx',sheet_name='Standard Data',index_col=0).T
raw_data.reset_index(drop=True,inplace=True)
raw_data=raw_data[:-4]
raw_data.dropna(inplace=True,axis=1)
raw_data.rename(columns={"BG (mg/dl)": "BG VAL"},inplace=True)
raw_data.head(3)
# Out:
# Variables Var1 Var2 Var3 Var4 Var5 Var6 Var7 Var8 Var9 Var10  ...   Var72  \
# 0          359  362  362  462  481  382  344  475  498   469  ...     531
# 1          372  369  405  373  450  386  435  338  409   366  ...     440
# 2          418  392  391  420  382  407  401  383  448   402  ...     403
#
# Variables Var73 Var74 Var75 Var76 Var77 Var78 Var79 Var80 BG VAL
# 0           533   521   535   535   538   538   540   540    102
# 1           394   386   422   377   430   398   378   423    102
# 2           393   384   462   412   376   410   430   402    102
#
# [3 rows x 81 columns]

# %%
raw_data.plot(kind='kde',figsize=(15,10));

# %%
raw_data['BG VAL'].plot()

# %%
random_state=42

from sklearn.model_selection import train_test_split
X,y=raw_data.drop(['BG VAL'],axis=1),raw_data['BG VAL']
#display(X)
X=scale_numerical_data(X,None) #'minmax,standard,normalizer
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=random_state)

# %%
clf_models=[LinearRegression(),
            RandomForestRegressor(random_state=random_state),
            GradientBoostingRegressor(random_state=random_state),
            SGDRegressor(random_state=random_state),
            KNeighborsRegressor(),
            AdaBoostRegressor(random_state=random_state),
            MLPRegressor()
    ]   
get_model_prediction(x_train,y_train,x_test,y_test,clf_models,True,False)
# Out:
# **Model name:  LinearRegression
# [188.44780161 201.40238539 180.84635272 237.3590384  263.80150724
#  268.31962068 326.10501973 271.12231962 169.27211549 192.74698654
#  416.1764311   -3.61395979 235.52153601 396.58465421 248.50610512]
#  ERROR MEASURES
# Root Mean Squared Error:  124.631886898812
# Mean Absolute Error:  97.84403932618872
# Mean Absolute Percent Error:  284.7738269537088
# R2 score:  -0.6686308177618223
#     BG VAL        pred
# 117    103  188.447802
# 19     115  201.402385
# 82     132  180.846353
# 97     249  237.359038
# 56     349  263.801507
# 12     143  268.319621
# 132    109  326.105020
# 65     347  271.122320
# 66     347  169.272115
# 18     143  192.746987
# 51     349  416.176431
# 78     132   -3.613960
# 94     249  235.521536
# 133    109  396.584654
# 100    249  248.506105
# **Model name:  RandomForestRegressor
# [152.6 176.1 218.6 224.5 299.2 197.9 209.2 126.9 209.1 148.2 259.3 232.2
#  177.  186.7 191.1]
#  ERROR MEASURES
# Root Mean Squared Error:  93.08582419824549
# Mean Absolute Error:  79.16000000000001
# Mean Absolute Percent Error:  42.883459954865316
# R2 score:  -3.7895647826251864
#     BG VAL   pred
# 117    103  152.6
# 19     115  176.1
# 82     132  218.6
# 97     249  224.5
# 56     349  299.2
# 12     143  197.9
# 132    109  209.2
# 65     347  126.9
# 66     347  209.1
# 18     143  148.2
# 51     349  259.3
# 78     132  232.2
# 94     249  177.0
# 133    109  186.7
# 100    249  191.1
# **Model name:  GradientBoostingRegressor
# [143.30802774 249.57227896 251.51989087 201.60297052 369.07961778
#  152.57281695 181.34349726 206.45568443 286.27894124 170.14525019
#  325.59574679 277.53749687 145.29849213 215.60128157 164.87506418]
#  ERROR MEASURES
# Root Mean Squared Error:  88.35334690239567
# Mean Absolute Error:  75.70488392608277
# Mean Absolute Percent Error:  36.092658860657934
# R2 score:  -0.7633683002957194
#     BG VAL        pred
# 117    103  143.308028
# 19     115  249.572279
# 82     132  251.519891
# 97     249  201.602971
# 56     349  369.079618
# 12     143  152.572817
# 132    109  181.343497
# 65     347  206.455684
# 66     347  286.278941
# 18     143  170.145250
# 51     349  325.595747
# 78     132  277.537497
# 94     249  145.298492
# 133    109  215.601282
# 100    249  164.875064
# **Model name:  SGDRegressor
# [4.13845698e+16 5.44766962e+16 6.00726252e+16 5.28934140e+16
#  5.23591788e+16 5.41170445e+16 3.94398135e+16 4.18744006e+16
#  4.64171422e+16 5.87462751e+16 5.01423512e+16 4.49711177e+16
#  4.05702372e+16 4.28417895e+16 4.91288427e+16]
#  ERROR MEASURES
# Root Mean Squared Error:  4.9060009509577544e+16
# Mean Absolute Error:  4.862903320441155e+16
# Mean Absolute Percent Error:  99.99999999999957
# R2 score:  -56.16839620184597
# C:\Users\ndrs\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
#     BG VAL          pred
# 117    103  4.138457e+16
# 19     115  5.447670e+16
# 82     132  6.007263e+16
# 97     249  5.289341e+16
# 56     349  5.235918e+16
# 12     143  5.411704e+16
# 132    109  3.943981e+16
# 65     347  4.187440e+16
# 66     347  4.641714e+16
# 18     143  5.874628e+16
# 51     349  5.014235e+16
# 78     132  4.497112e+16
# 94     249  4.057024e+16
# 133    109  4.284179e+16
# 100    249  4.912884e+16
# **Model name:  KNeighborsRegressor
# [217.4 176.6 176.6 129.6 217.8 131.8 106.2 136.8 286.6 131.8 257.0 210.0
#  161.0 163.6 286.6]
#  ERROR MEASURES
# Root Mean Squared Error:  91.33043304397499
# Mean Absolute Error:  74.47999999999999
# Mean Absolute Percent Error:  42.23867458860753
# R2 score:  -1.6619137517505154
#     BG VAL   pred
# 117    103  217.4
# 19     115  176.6
# 82     132  176.6
# 97     249  129.6
# 56     349  217.8
# 12     143  131.8
# 132    109  106.2
# 65     347  136.8
# 66     347  286.6
# 18     143  131.8
# 51     349    257
# 78     132    210
# 94     249    161
# 133    109  163.6
# 100    249  286.6
# **Model name:  AdaBoostRegressor
# [226.         193.57317073 228.78571429 201.05747126 337.0625
#  196.86842105 209.85       267.51851852 226.13461538 193.57317073
#  228.78571429 208.72727273 192.33333333 209.27777778 211.32258065]
#  ERROR MEASURES
# Root Mean Squared Error:  83.54320647588563
# Mean Absolute Error:  77.02938625834004
# Mean Absolute Percent Error:  35.59499133483943
# R2 score:  -4.340729631144936
#     BG VAL        pred
# 117    103  226.000000
# 19     115  193.573171
# 82     132  228.785714
# 97     249  201.057471
# 56     349  337.062500
# 12     143  196.868421
# 132    109  209.850000
# 65     347  267.518519
# 66     347  226.134615
# 18     143  193.573171
# 51     349  228.785714
# 78     132  208.727273
# 94     249  192.333333
# 133    109  209.277778
# 100    249  211.322581
# **Model name:  MLPRegressor
# [314.09023869 526.27256867 458.51761472 360.63176128 423.1753329
#  383.24141972 261.2887296  284.33802024 312.10833353 483.88271922
#  307.76334326 452.87745068 308.30819997 326.90713975 433.37173757]
#  ERROR MEASURES
# Root Mean Squared Error:  220.6341008252179
# Mean Absolute Error:  185.9570143823192
# Mean Absolute Percent Error:  46.82491228156443
# R2 score:  -6.778841993473422
#     BG VAL        pred
# 117    103  314.090239
# 19     115  526.272569
# 82     132  458.517615
# 97     249  360.631761
# 56     349  423.175333
# 12     143  383.241420
# 132    109  261.288730
# 65     347  284.338020
# 66     347  312.108334
# 18     143  483.882719
# 51     349  307.763343
# 78     132  452.877451
# 94     249  308.308200
# 133    109  326.907140
# 100    249  433.371738

# %% [markdown]
# ## Linear Coefficients

# %% [markdown]
# ### Using 90% of data

# %%
model = LinearRegression()
model.fit(x_train, y_train)
pred=model.predict(x_test)
clf_metrics=acc_score(y_test,pred)
plot_test_data(y_test,pred)
intercept = model.intercept_
print('the intercept of the linear model is',intercept)
for idx, col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name, model.coef_[idx]))
# Out:
#  ERROR MEASURES
# Root Mean Squared Error:  124.631886898812
# Mean Absolute Error:  97.84403932618872
# Mean Absolute Percent Error:  284.7738269537088
# R2 score:  -0.6686308177618223
#     BG VAL        pred
# 117    103  188.447802
# 19     115  201.402385
# 82     132  180.846353
# 97     249  237.359038
# 56     349  263.801507
# 12     143  268.319621
# 132    109  326.105020
# 65     347  271.122320
# 66     347  169.272115
# 18     143  192.746987
# 51     349  416.176431
# 78     132   -3.613960
# 94     249  235.521536
# 133    109  396.584654
# 100    249  248.506105
# the intercept of the linear model is 64.61764479452643
# The coefficient for Var1 is -0.13471379360847044
# The coefficient for Var2 is -0.1042753017420938
# The coefficient for Var3 is -0.36358036147838857
# The coefficient for Var4 is 0.3539336674576746
# The coefficient for Var5 is -0.1850609678788951
# The coefficient for Var6 is 0.17742719003832702
# The coefficient for Var7 is 0.15365305789690525
# The coefficient for Var8 is -0.3635730225315871
# The coefficient for Var9 is 0.09064609420433006
# The coefficient for Var10 is -0.1733972150430536
# The coefficient for Var11 is 0.06338801702260224
# The coefficient for Var12 is 0.19919262242214464
# The coefficient for Var13 is 0.06900461492713222
# The coefficient for Var14 is -0.16565261152002772
# The coefficient for Var15 is 0.24215948945118515
# The coefficient for Var16 is -0.10021348581957629
# The coefficient for Var17 is -0.24950752389740088
# The coefficient for Var18 is -0.2703781607811894
# The coefficient for Var19 is 0.318148177239033
# The coefficient for Var20 is -0.110530350888799
# The coefficient for Var21 is 0.3613073683071097
# The coefficient for Var22 is -0.5287923675339754
# The coefficient for Var23 is -0.19958560788476326
# The coefficient for Var24 is 0.2649974860102016
# The coefficient for Var25 is -0.21573202949435788
# The coefficient for Var26 is -0.24603738155043525
# The coefficient for Var27 is 0.4347087819115337
# The coefficient for Var28 is 0.09573002639861838
# The coefficient for Var29 is 0.1112927507059768
# The coefficient for Var30 is 0.051285959537608616
# The coefficient for Var31 is -0.10453854185928926
# The coefficient for Var32 is -0.14033574851152475
# The coefficient for Var33 is 0.08179251741207752
# The coefficient for Var34 is 0.09205632105704249
# The coefficient for Var35 is -0.3247823442394599
# The coefficient for Var36 is 0.3678352437263359
# The coefficient for Var37 is 0.2505159718314219
# The coefficient for Var38 is -0.32361014487181056
# The coefficient for Var39 is 0.5647148572481167
# The coefficient for Var40 is 0.03572095162173916
# The coefficient for Var41 is -0.7403611523711
# The coefficient for Var42 is 0.4733671625068856
# The coefficient for Var43 is -0.4742492074384172
# The coefficient for Var44 is 0.1443288765808117
# The coefficient for Var45 is 0.08585682390041616
# The coefficient for Var46 is -0.3449745364940672
# The coefficient for Var47 is 0.16444272253048214
# The coefficient for Var48 is 0.031581324862503646
# The coefficient for Var49 is 0.443853809979176
# The coefficient for Var50 is -0.12875175613451312
# The coefficient for Var51 is 0.08062132816230283
# The coefficient for Var52 is 0.2948626771552476
# The coefficient for Var53 is 0.30008405015170503
# The coefficient for Var54 is -0.11587555232705532
# The coefficient for Var55 is -0.19817111914701158
# The coefficient for Var56 is -0.03879676324360232
# The coefficient for Var57 is -0.23776658768534537
# The coefficient for Var58 is 0.05326463075162219
# The coefficient for Var59 is 0.09784168610493468
# The coefficient for Var60 is -0.01751973214989483
# The coefficient for Var61 is -0.33419047843607597
# The coefficient for Var62 is 0.41601940008392435
# The coefficient for Var63 is -0.21726963256470838
# The coefficient for Var64 is 0.2412028508085093
# The coefficient for Var65 is 0.09533711426067068
# The coefficient for Var66 is 0.2865352331704676
# The coefficient for Var67 is -0.49007807582005836
# The coefficient for Var68 is 0.218382022332995
# The coefficient for Var69 is -0.5905200503532664
# The coefficient for Var70 is 0.4017146830681033
# The coefficient for Var71 is 0.12324941214216709
# The coefficient for Var72 is -0.12883728823410168
# The coefficient for Var73 is 0.18786596825610657
# The coefficient for Var74 is -0.010871744917716475
# The coefficient for Var75 is -0.15054389215036942
# The coefficient for Var76 is -0.23806565291815784
# The coefficient for Var77 is -0.09065406462076711
# The coefficient for Var78 is -0.05807893378317763
# The coefficient for Var79 is 0.05673818601498058
# The coefficient for Var80 is 0.5280241552058984

# %% [markdown]
# ### Using all the data

# %%
model = LinearRegression()
model.fit(X, y)
intercept = model.intercept_
print('the intercept of the linear model is',intercept)
for idx, col_name in enumerate(x_train.columns):
    print("The coefficient for {} is {}".format(col_name, model.coef_[idx]))
# Out:
# the intercept of the linear model is 67.8750595197497
# The coefficient for Var1 is -0.28819113595256746
# The coefficient for Var2 is -0.12103418215883202
# The coefficient for Var3 is -0.25509954724735645
# The coefficient for Var4 is 0.4313195703630214
# The coefficient for Var5 is -0.11553273377694809
# The coefficient for Var6 is 0.19499826339578108
# The coefficient for Var7 is -0.01811859935960102
# The coefficient for Var8 is -0.4037012772054764
# The coefficient for Var9 is 0.0426892498354927
# The coefficient for Var10 is -0.14451838984105
# The coefficient for Var11 is 0.0828365929461638
# The coefficient for Var12 is 0.04210017742810904
# The coefficient for Var13 is -0.026665512303052946
# The coefficient for Var14 is 0.02759721704953927
# The coefficient for Var15 is 0.35390746994620303
# The coefficient for Var16 is -0.04328261294064159
# The coefficient for Var17 is 0.03909487123964831
# The coefficient for Var18 is -0.3743260894298647
# The coefficient for Var19 is 0.3618363189865257
# The coefficient for Var20 is -0.10051025571131672
# The coefficient for Var21 is 0.32770735276213026
# The coefficient for Var22 is -0.4330719505714268
# The coefficient for Var23 is -0.11470381443388783
# The coefficient for Var24 is 0.20644650411908208
# The coefficient for Var25 is -0.36717036223271277
# The coefficient for Var26 is -0.18814354045932294
# The coefficient for Var27 is 0.19340150188502694
# The coefficient for Var28 is 0.3047562993698729
# The coefficient for Var29 is -0.0946543263759814
# The coefficient for Var30 is -0.016860767089082254
# The coefficient for Var31 is -0.09116594377935208
# The coefficient for Var32 is -0.12294391418083317
# The coefficient for Var33 is 0.2947914284295759
# The coefficient for Var34 is 0.21476625143489614
# The coefficient for Var35 is -0.19489329394251598
# The coefficient for Var36 is 0.21196898803425762
# The coefficient for Var37 is 0.1348387278664522
# The coefficient for Var38 is -0.28925333253258045
# The coefficient for Var39 is 0.5163303283507925
# The coefficient for Var40 is -0.16093565071743116
# The coefficient for Var41 is -0.4320923225213462
# The coefficient for Var42 is 0.45665057891142774
# The coefficient for Var43 is -0.4458882848701162
# The coefficient for Var44 is 0.08839683794807923
# The coefficient for Var45 is -0.03995623523829095
# The coefficient for Var46 is -0.2538008856139494
# The coefficient for Var47 is 0.11897701039129271
# The coefficient for Var48 is 0.0781454823140049
# The coefficient for Var49 is 0.39906150153914827
# The coefficient for Var50 is -0.1361266590298167
# The coefficient for Var51 is -0.029845575774175376
# The coefficient for Var52 is 0.26763854956317734
# The coefficient for Var53 is 0.2460901663579027
# The coefficient for Var54 is -0.08696334711135362
# The coefficient for Var55 is -0.19204756226526062
# The coefficient for Var56 is -0.06207933772669527
# The coefficient for Var57 is -0.16089932285942432
# The coefficient for Var58 is -0.0570430526373496
# The coefficient for Var59 is 0.01589174583820141
# The coefficient for Var60 is 0.11533459051691487
# The coefficient for Var61 is -0.19515445476115748
# The coefficient for Var62 is 0.218758316524638
# The coefficient for Var63 is -0.22567033617924784
# The coefficient for Var64 is 0.2511376393976074
# The coefficient for Var65 is 0.15797872189254825
# The coefficient for Var66 is 0.22190950636832563
# The coefficient for Var67 is -0.2869776059977469
# The coefficient for Var68 is 0.11393652047172298
# The coefficient for Var69 is -0.5620659938401198
# The coefficient for Var70 is 0.38696704507875984
# The coefficient for Var71 is 0.16153748353250147
# The coefficient for Var72 is -0.10097338959474966
# The coefficient for Var73 is 0.08448592244235686
# The coefficient for Var74 is -0.013371837305520738
# The coefficient for Var75 is -0.17976792129151303
# The coefficient for Var76 is -0.15537442190125458
# The coefficient for Var77 is -0.16020317486357
# The coefficient for Var78 is -0.013258624309775813
# The coefficient for Var79 is -0.03537764970633919
# The coefficient for Var80 is 0.5967034405592437

# %% [markdown]
# ## Model Predictions

# %%
new_data=pd.read_excel('STANDARDS-WEARABLE-NATRAJ PREDICTION.xlsx',sheet_name='PREDICTION-DETAILS',header=None,
                      usecols="G", na_values=['Orig ADC']).dropna().T
y_test=new_data[0]
x_test=new_data.drop([0],axis=1)

# %%
clf_models=[LinearRegression(),
            RandomForestRegressor(random_state=random_state),
            GradientBoostingRegressor(random_state=random_state),
            SGDRegressor(random_state=random_state),
            KNeighborsRegressor(),
            AdaBoostRegressor(random_state=random_state),
            MLPRegressor()
    ]

x_test=scale_numerical_data(x_test)
get_model_prediction(X,y,x_test,None,clf_models)
print('Actual Glucose Level',y_test)
# Out:
# **Model name:  LinearRegression
# [368.55030421]
# **Model name:  RandomForestRegressor
# [196.4]
# **Model name:  GradientBoostingRegressor
# [195.45231702]
# **Model name:  SGDRegressor
# [45.61276059]
# **Model name:  KNeighborsRegressor
# [161.4]
# **Model name:  AdaBoostRegressor
# [193.5]
# **Model name:  MLPRegressor
# C:\Users\ndrs\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\Users\ndrs\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [3.71086906]
# Actual Glucose Level 0    442.0
# Name: 0, dtype: float64
